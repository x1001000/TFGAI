# %%
import numpy as np
import matplotlib.pyplot as plt
radians = np.linspace(0, np.pi, 1001000)
Xs = np.sin(radians)
Ys = np.cos(radians) + np.power(Xs, 2/3)
plt.plot( Xs, Ys, 'red', label='TFGAI')
plt.plot(-Xs, Ys, 'red', label='to be coding or not to be coding')
plt.legend()
